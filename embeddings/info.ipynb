# %%
import pandas as pd

# %%
df = pd.read_pickle("./embeddings.pkl")
df
# Out:
#                                                  filename  \
# 0       dataset/manipulated_frames/youtube/480/face_7.jpg
# 1       dataset/manipulated_frames/youtube/480/face_8.jpg
# 2       dataset/manipulated_frames/youtube/480/face_14...
# 3       dataset/manipulated_frames/youtube/480/face_24...
# 4       dataset/manipulated_frames/youtube/480/face_1.jpg
# ...                                                   ...
# 233835  dataset/manipulated_frames/NeuralTextures/114_...
# 233836  dataset/manipulated_frames/NeuralTextures/114_...
# 233837  dataset/manipulated_frames/NeuralTextures/114_...
# 233838  dataset/manipulated_frames/NeuralTextures/114_...
# 233839  dataset/manipulated_frames/NeuralTextures/114_...
#
#                                            face_embedding
# 0       [0.012866516, 0.042880464, 0.0228739, 0.024033...
# 1       [-0.0184556, 0.017823523, 0.004430527, 0.00696...
# 2       [0.0020168228, 0.035098616, 0.059355486, 0.038...
# ...
